# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 3 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print ("Sara Perez")
# Out:
# Sara Perez

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print ("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy" and "pandas"

# %%
# Write your answer here


import pandas as pd 
import numpy as np

# %% [markdown]
# <font size = "5">
#
# (a) Replace the values of a column
#
# <font size = "3">
#
# - Import the "data_raw/constructors.csv" file
# - Replace the values "British", "American", and "Dutch" with <br>
# "UK", "USA", "Netherlands" in the column "nationality"
#
#
# HINT: See the example in Lecture 12

# %%
# Write your own code

constructors = pd.read_csv("data_raw/constructors.csv")

constructors ["nationality"] = constructors ["nationality"].replace("British", "UK")

constructors ["nationality"] = constructors ["nationality"].replace("American", "USA")

constructors ["nationality"] = constructors ["nationality"].replace("Dutch", "Netherlands")

# %% [markdown]
# <font size = "5">
#
#
# <span style="color:red"> For QUESTIONS (b)-(e): </span>
#
# <span style="color:red"> Import the "data_raw/sprint_results.csv" file </span>
#
#
# (b) Recode a numeric colum
#
# <font size = "3">
#
# - Recode the "points" column into a new column "points_brackets" <br>
# with the following categories
#
# $\qquad$ ``` ["0-20","21-30","31-100"] ```
#
# $\qquad$ HINT: Use the "pd.cut()" command. See Lecture 12 <br>
# $\qquad$ HINT: Be careful about the left and right points of <br>
# $\qquad$ interval to make sure that you classify the points correctly

# %%
# Write your own code:

results = pd.read_csv("data_raw/sprint_results.csv")

bins_x = [0, 20, 21, 30, 31,100]
labels_x = ["Between 0-20",
          "Between 21-30",
          "Between 31-100"]

results["points_brackets"] = pd.cut(results["points"],
                              bins = bins_x,
                              right = False,
                              #left = True,
                              labels = labels_x)
results 

#classify left and right? bins must be fewer than # of edges?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 10
#       5 bins_x = [0, 20, 21, 30, 31,100]
#       6 labels_x = ["Between 0-20",
#       7           "Between 21-30",
#       8           "Between 31-100"]
# ---> 10 results["points_brackets"] = pd.cut(results["points"],
#      11                               bins = bins_x,
#      12                               right = False,
#      13                               #left = True,
#      14                               labels = labels_x)
#      15 results
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/tile.py:293, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     290     if (np.diff(bins.astype("float64")) < 0).any():
#     291         raise ValueError("bins must increase monotonically.")
# --> 293 fac, bins = _bins_to_cuts(
#     294     x,
#     295     bins,
#     296     right=right,
#     297     labels=labels,
#     298     precision=precision,
#     299     include_lowest=include_lowest,
#     300     dtype=dtype,
#     301     duplicates=duplicates,
#     302     ordered=ordered,
#     303 )
#     305 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/tile.py:453, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     451 else:
#     452     if len(labels) != len(bins) - 1:
# --> 453         raise ValueError(
#     454             "Bin labels must be one fewer than the number of bin edges"
#     455         )
#     456 if not is_categorical_dtype(labels):
#     457     labels = Categorical(
#     458         labels,
#     459         categories=labels if len(set(labels)) == len(labels) else None,
#     460         ordered=ordered,
#     461     )
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %% [markdown]
# <font size = "5">
#
# (c) Aggregate and query
#
# <font size = "3">
#
# - Subset the observations for 'raceId <= 1070' using ```.query()```
# - Obtain the maximum of "points" by "driverId" <br>  using ``` .groupby().agg() ``` and save this to <br>
# a new dataset called "aggregate_data"
# - From "aggregate_data" subset the drivers with a maximum number of points $>= 1$
# - Display the resulting dataset
#
#
# Hint: See Lecture 15

# %%
# Write your own code

subset_agg = (results.query("raceId <= 1070")
                .groupby('points')
                .agg({'driverId': ['mean', 'std']}))
subset_agg
# Out:
#           driverId
#               mean         std
# points
# 0       670.323529  341.730686
# 1       819.500000    3.535534
# 2       415.500000  586.191522
# 3       826.000000    5.656854

# %% [markdown]
# <font size = "5">
#
# (d) Aggregate and sort
#
# <font size = "3">
#
# - Obtain the mean of "points" by "driverId" <br>  using ``` .groupby().agg() ```
# - Sort the drivers in descending order using of <br>
# the mean of points using ``` .sort_values() ```
#
#
# Hint: See Lecture 15

# %%
# Write your own code

grouped_sorted = (results.groupby('points')
                    .agg({'driverId': 'mean'})
                    .sort_values(by='points', ascending=False))

grouped_sorted
# Out:
#           driverId
# points
# 8       835.666667
# 7       840.000000
# 6       549.333333
# 5       836.333333
# 4       825.333333
# 3       829.000000
# 2       692.333333
# 1       687.000000
# 0       670.172414

# %% [markdown]
# <font size = "5">
#
# (e) Rename column
#
# <font size = "3">
#
# - Rename the column "grid" to "grid_placement"
#
# HINT: Create a dictionary and use ```.rename(columns = ...)``` <br>
# See Lecture 15

# %%
# Write your own code

rename_dict = {'grid': 'grid_placement'}
results.rename(columns=rename_dict, inplace=True)

# %% [markdown]
# <font size = "5">
#
# (f) Merge dataset
#
# <font size = "3">
#
# - Create a new dataset with  ```pd.merge()``` using <br>
# "sprint_results" as the primary dataset, and <br>
# "constructors" as the secondary dataset, merging on <br>
# the column "constructorId"
# - To get full points **ONLY** merge the "nationality" column <br>
# from the secondary dataset (not all the columns)
#
# HINT: Use ```[[...]]``` to extract a subset of columns <br>
# from the secondary dataset before merging, including the <br>
# "constructorId" column. <br>
# Be careful to notice that "constructorId" has an uppercase "I".
#
# See Lecture 15

# %%
# Write your own code



#columns_to_keep = ['constructorId', 'nationality']
#merged_df = pd.merge(results, constructors[natonality], on='constructorId', how='left')
#display(merged_results[['constructorId', 'nationality']])


#results_merge = pd.merge(results[['constructorId']],
                       #constructors[["nationality"]],
                       #on = "constructorId",
                       #how = "left")
#results_merge


results_merge = pd.merge(results,
                         constructors[["constructorId","nationality"]],
                         on = "constructorId",
                         how = "left")
results_merge
# Out:
#      resultId  raceId  driverId  constructorId  number  grid position  \
# 0           1    1061       830              9      33     2        1
# 1           2    1061         1            131      44     1        2
# 2           3    1061       822            131      77     3        3
# 3           4    1061       844              6      16     4        4
# 4           5    1061       846              1       4     6        5
# ..        ...     ...       ...            ...     ...   ...      ...
# 115       116    1095       840            117      18    15       16
# 116       117    1095       839            214      31     6       17
# 117       118    1095         4            214      14     7       18
# 118       119    1095       849              3       6    16       19
# 119       120    1095       848              3      23    11       \N
#
#     positionText  positionOrder  points  laps       time milliseconds  \
# 0              1              1       3    17  25:38.426      1538426
# 1              2              2       2    17     +1.430      1539856
# 2              3              3       1    17     +7.502      1545928
# 3              4              4       0    17    +11.278      1549704
# 4              5              5       0    17    +24.111      1562537
# ..           ...            ...     ...   ...        ...          ...
# 115           16             16       0    24    +50.700      1862007
# 116           17             17       0    24    +51.756      1863063
# 117           18             18       0    24    +53.985      1865292
# 118           19             19       0    24  +1:16.850      1888157
# 119            R             20       0    12         \N           \N
#
#     fastestLap fastestLapTime  statusId nationality
# 0           14       1:30.013         1    Austrian
# 1           17       1:29.937         1      German
# 2           17       1:29.958         1      German
# 3           16       1:30.163         1     Italian
# 4           16       1:30.566         1          UK
# ..         ...            ...       ...         ...
# 115          4       1:15.425         1          UK
# 116          5       1:16.097         1      French
# 117          5       1:14.764         1      French
# 118          4       1:16.525         1          UK
# 119          4       1:15.998        31          UK
#
# [120 rows x 17 columns]
